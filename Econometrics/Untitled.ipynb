# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import scipy
#import modules that describe distributions
from scipy import stats
from scipy.stats import kurtosis
from scipy.stats import skew
#turn off warnings for sns depreciated versions- this is the best
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"C:\Users\zgeorge\Dropbox (CMN Hospitals)\George\School\Fall 2018\Econometrics\Project\Citizenship Data.xlsx",sheet_name="no_null")

# %%
df.head(5)
# Out:
#                Lookup  Year    Geography  Total Population  \
# 0  Abilene, TX - 2013  2013  Abilene, TX            168144
# 1  Abilene, TX - 2014  2014  Abilene, TX            166900
# 2  Abilene, TX - 2015  2015  Abilene, TX            168922
# 3  Abilene, TX - 2016  2016  Abilene, TX            170860
# 4  Abilene, TX - 2017  2017  Abilene, TX            169747
#
#    US Citizens by Birth  U.S. citizen by naturalization  Non-citizen  \
# 0                160182                            2868         5094
# 1                159997                            3226         3677
# 2                160196                            3851         4875
# 3                161795                            3669         5396
# 4                157924                            5536         6287
#
#    Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 0            477                                     1    37      125
# ...

# %%
df = df.drop(['Lookup','Total sanctuary years'],axis=1)

# %%
df.head(5)
# Out:
#    Year    Geography  Total Population  US Citizens by Birth  \
# 0  2013  Abilene, TX            168144                160182
# 1  2014  Abilene, TX            166900                159997
# 2  2015  Abilene, TX            168922                160196
# 3  2016  Abilene, TX            170860                161795
# 4  2017  Abilene, TX            169747                157924
#
#    U.S. citizen by naturalization  Non-citizen  Violent crime  \
# 0                            2868         5094            477
# 1                            3226         3677            571
# 2                            3851         4875            613
# 3                            3669         5396            546
# 4                            5536         6287            636
#
#    Murder and nonnegligent manslaughter  Rape  Robbery  Aggravated assault  \
# 0                                     1    37      125                 314
# ...

# %%
def showmethedist(x):
    print("mean : ", np.mean(x))
    print("var  : ", np.var(x))
    print("skew : ",skew(x))
    print("kurt : ",kurtosis(x))

# %%
fig, ax = plt.subplots()
sns.distplot(df['Total Population'],50,color='red')
plt.title('Distribution of Total Population')
ax.set_xlabel('Total Population')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(df['Total Population'])
# Out:
# mean :  707607.9321033211
# var  :  1993714802082.9617
# skew :  4.898826858997465
# kurt :  30.71542867695836

# %%
logged_pop = np.log(df['Total Population'])
fig, ax = plt.subplots()
sns.distplot(logged_pop,50,color='red')
plt.title('Distribution of Total Population')
ax.set_xlabel('Logged Total Population')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(logged_pop)
# Out:
# mean :  12.694512456973376
# var  :  1.1359467899887552
# skew :  1.095462153628589
# kurt :  0.7088655213501438

# %%
df['Total Population'] = logged_pop

# %%
fig, ax = plt.subplots()
sns.distplot(df['US Citizens by Birth'],50,color='blue')
plt.title('Distribution of Total Population')
ax.set_xlabel('Total Population')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(df['US Citizens by Birth'])
# Out:
# mean :  601227.6900369003
# var  :  1176715709375.8452
# skew :  4.244069182766995
# kurt :  22.036336139509814

# %%
logged_uscit = np.log(df['US Citizens by Birth'])
fig, ax = plt.subplots()
sns.distplot(logged_uscit,50,color='red')
plt.title('Distribution of Total Population')
ax.set_xlabel('Logged Total US Citizens')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(logged_uscit)
# Out:
# mean :  12.603626796979077
# var  :  1.053889732145259
# skew :  1.0715110676613846
# kurt :  0.5769393236264517

# %%
df['US Citizens by Birth'] = logged_uscit

# %%
fig, ax = plt.subplots()
sns.distplot(df['U.S. citizen by naturalization'],50,color='blue')
plt.title('Distribution of Total Population')
ax.set_xlabel('Total Population')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(df['U.S. citizen by naturalization'])
# Out:
# mean :  51178.18450184502
# var  :  35957019819.638275
# skew :  7.990042913415165
# kurt :  78.41021990976097

# %%
logged_uscitnat = np.log(df['U.S. citizen by naturalization'])
fig, ax = plt.subplots()
sns.distplot(logged_uscitnat,50,color='red')
plt.title('Distribution of Total Population')
ax.set_xlabel('Logged Total US Citizens')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(logged_uscitnat)
# Out:
# mean :  9.052187128132566
# var  :  2.7652958108592696
# skew :  0.7231423220537019
# kurt :  0.33854930250556103

# %%
df['U.S. citizen by naturalization'] = logged_uscitnat

# %%
fig, ax = plt.subplots()
sns.distplot(df['Non-citizen'],50,color='blue')
plt.title('Distribution of Total Population')
ax.set_xlabel('Total Population')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(df['Non-citizen'])
# Out:
# mean :  55202.05756457565
# var  :  33522685933.13174
# skew :  7.574935602516562
# kurt :  72.52598741208864

# %%
logged_noncit = np.log(df['Non-citizen'])
fig, ax = plt.subplots()
sns.distplot(logged_noncit,50,color='red')
plt.title('Distribution of Total Population')
ax.set_xlabel('Logged Total US Citizens')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(logged_noncit)
# Out:
# mean :  9.299275860706922
# var  :  2.711977786557711
# skew :  0.5050535668783549
# kurt :  0.1761350871728702

# %%
df['Non-citizen'] = logged_noncit

# %%
fig, ax = plt.subplots()
sns.distplot(df['Total Violent Crime'],50,color='blue')
plt.title('Distribution of Total Population')
ax.set_xlabel('Total Population')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(df['Total Violent Crime'])
# Out:
# mean :  21038.99852398524
# var  :  1589138592.4029508
# skew :  4.486684660328345
# kurt :  25.882282515407333

# %%
logged_totcrime = np.log(df['Total Violent Crime'])
fig, ax = plt.subplots()
sns.distplot(logged_totcrime,50,color='red')
plt.title('Distribution of Total Population')
ax.set_xlabel('Logged Total US Citizens')
ax.set_ylabel('# of Metros')
plt.show()

showmethedist(logged_totcrime)
# Out:
# mean :  9.104566503142593
# var  :  1.4656358651469845
# skew :  0.4935921641860029
# kurt :  0.26024872907658514

# %%
df['Total Violent Crime'] = logged_totcrime
df['percent_noncit'] = df['Non-citizen']/df['Total Population']
df.head(5)
# Out:
#    Year    Geography  Total Population  US Citizens by Birth  \
# 0  2013  Abilene, TX         12.032576             11.984066
# 1  2014  Abilene, TX         12.025150             11.982910
# 2  2015  Abilene, TX         12.037192             11.984153
# 3  2016  Abilene, TX         12.048600             11.994085
# 4  2017  Abilene, TX         12.042064             11.969869
#
#    U.S. citizen by naturalization  Non-citizen  Violent crime  \
# 0                        7.961370     8.535819            477
# 1                        8.078998     8.209852            571
# 2                        8.256088     8.491875            613
# 3                        8.207674     8.593413            546
# 4                        8.619027     8.746239            636
#
#    Murder and nonnegligent manslaughter  Rape  Robbery  Aggravated assault  \
# 0                                     1    37      125                 314
# ...

# %%
sns.regplot('Total Violent Crime','Total Population',df,fit_reg=True,scatter_kws={'alpha':0.45})

# %%
sns.regplot('Total Violent Crime','US Citizens by Birth',df,fit_reg=True,scatter_kws={'alpha':0.45})

# %%
sns.regplot('Total Violent Crime','U.S. citizen by naturalization',df,fit_reg=True,scatter_kws={'alpha':0.45})

# %%
sns.regplot('Total Violent Crime','Non-citizen',df,fit_reg=True,scatter_kws={'alpha':0.45})

# %%
sns.regplot('Total Violent Crime','percent_noncit',df,fit_reg=True,scatter_kws={'alpha':0.45})

# %%
df = df.drop(['US Citizens by Birth','Violent crime','Property crime'],axis=1)
#Create a list that displays only numeric variables
numeric_var=df.select_dtypes(include=[np.number]).columns
#Here we set up our correlation matrix for numeric variables
correlation=df[numeric_var].corr()
#Pull the max (whether positive or negative) correlation of each variable to another variable
aux=(abs(correlation)-np.identity(correlation.shape[0])).max()

# %%
#Throw out any variables that don't have at least .7 correlation with something else
selected_feats=aux[(aux>0.55)].index
sns.set()
fig, ax = plt.subplots(figsize=(16,8))
#make the plot have numbers, a legend and pretty colors
sns.heatmap(correlation.loc[selected_feats,selected_feats], annot=True,fmt='.2f',ax=ax,cmap="BrBG",center=0)
plt.title('High Correlation Variables',fontsize=16)
#show the plot
plt.show()

# %%
correlation=df[numeric_var].corr() #calculate again the correlation matrix (without the removed columns)
aux=abs(correlation['Total Violent Crime']).sort_values(ascending=False) #sort variables by their correlation with SalePrice
selected_feats=aux[0:24].index #Take the best 24.
sns.set()
fig, ax = plt.subplots(figsize=(16,8))
sns.heatmap(correlation.loc[selected_feats,selected_feats], annot=True,fmt='.2f',ax=ax,cmap="BrBG",center=0)
plt.show()

# %%
from pandas.tools.plotting import lag_plot

# %%
tdf = pd.DataFrame()
tdf['year']=df['Year']
tdf['vcs']=df['Total Violent Crime']
lag_plot(tdf)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-a4f09b620e4e> in <module>()
#       1 tdf = pd.DataFrame()
# ----> 2 tdf['year']=df['Year']
#       3 tdf['vcs']=df['Total Violent Crime']
#       4 lag_plot(tdf)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
## source: http://scikit-learn.org/0.15/auto_examples/plot_learning_curve.html
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring=make_scorer(mean_squared_error))
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
from sklearn.linear_model import SGDRegressor, ElasticNetCV
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import learning_curve, train_test_split, RandomizedSearchCV

# %%
df = df.drop('Geography',axis=1)
scaler = StandardScaler()
scaler.fit(df)
scaled_train = scaler.transform(df)

# %%
target = df['Total Violent Crime']
df = df.drop('Total Violent Crime',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.31, random_state=42)

# %%
param_options = {"eta0": [.00001, .00004, .0004, .0001, .001,.004, .01, .04],
                 "tol": [.01, .001, .0001],
                 "loss":['squared_loss','huber', 'epsilon_insensitive','squared_epsilon_insensitive'],
                "penalty":['none', 'l2', 'l1', 'elasticnet'],
                "l1_ratio":[.00001,.001,.01,.1,.15,.3,.5,.75,.89,.99]}

lin = SGDRegressor()

n_it = 30
lin = RandomizedSearchCV(lin,param_distributions=param_options,n_iter=n_it,
                                  cv=9, scoring='neg_mean_squared_error',random_state=42)

lin.fit(X_train, y_train)

print("Best Parameters: {}".format(lin.best_params_))
print("Best Negative MSE: {}".format(lin.best_score_))
print("Predicted MSE: {}".format(mean_squared_error(y_test, lin.predict(X_test,))))
# Out:
# Best Parameters: {'tol': 0.001, 'penalty': 'elasticnet', 'loss': 'epsilon_insensitive', 'l1_ratio': 0.99, 'eta0': 1e-05}
# Best Negative MSE: -5916.296880602099
# Predicted MSE: 14646.244116091588

# %%
plot_learning_curve(lin, "Learning Curve", X_train, y_train, cv=9,)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\zgeorge\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
from sklearn.utils import resample
n_bootstraps = 1000
bootstrap_X = []
bootstrap_y = []
for _ in range(n_bootstraps):
    sample_X, sample_y = resample(df, target)
    bootstrap_X.append(sample_X)
    bootstrap_y.append(sample_y)
linear_regression_model = SGDRegressor(tol= 0.001, penalty= 'elasticnet', loss= 'epsilon_insensitive', l1_ratio= 0.99, eta0= 1e-05)
coeffs = []
for i, data in enumerate(bootstrap_X):
    linear_regression_model.fit(data, bootstrap_y[i])
    coeffs.append(linear_regression_model.coef_)

# %%
coef_df = pd.DataFrame(coeffs, columns=boston_df.columns)
coef_df.plot(kind='box')
plt.xticks(rotation=90)
